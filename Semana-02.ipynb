# %% [markdown]
# ## **Semana 02** : Mostrar comandos

# %%
# Pruebas de codigo

i = 1
print(i)
a = 10
b = 3

print("como te va {}. es {} ".format(a,b))
# Out:
# 1
# como te va 10. es 3

# %%
j = 10
print(j)

c = 10;
# Out:
# 10

# %%
for i in range(0,9):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for i in range(0,9):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
