# %% [markdown]
# # **Laboratorio 02**
#
# ## Introducción a la programación
#
# La programación es el proceso que se utiliza para diseñar e implementar un programa de computadora, valiéndose de algún lenguaje que permita comunicar una serie de acciones que se requiere que la computadora realice. ¿Qué es un programa? Es una caja negra que recibe alguna información, la cual es llamada "input" (entrada), realiza alguna acción, y devuelve información, la cual es llamada "output" (salida).
#
# ## Lenguajes de programación
# Un lenguaje de programación es una serie de instrucciones, las cuales permiten a un programador escribir secuencias de órdenes para controlar el comportamiento físico y lógico de una computadora, con el objetivo de que produzca diversas acciones deseadas por el programador (¡y los usuarios!).
#
# Algunos de los lenguajes mas populares en los últimos tiempos son Python, Java, C++, JavaScript y PHP.
#
# ## ¿Por qué Python?
# Elegimos Python porque es uno de los lenguajes de programación con reglas más simples e intuitivas que existen; esto explica la creciente popularidad que ha tenido en los ultimos tiempos.

# %% [markdown]
# ### 1.- Función **print()** :

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# ### 2,- Concatenar cadenas

# %%
# Defino una cadena

nombre = "Juan" #  defino una cadena

print("Me llamo :"  + nombre)
print("Me llamo :"  , nombre)
print("Me llamo : %s  " % (nombre) )
# Out:
# Me llamo :Juan
# Me llamo : Juan
# Me llamo : Juan

# %%
nombre = "Jaime"
apellido_p = "Gomez"

print("Mi nombre es :" + nombre)
print("Mi apellido es :" + apellido_p)

print("Mi nombre es : %s y mi apellido es : %s" %(nombre, apellido_p))
# Out:
# Mi nombre es :Jaime
# Mi apellido es :Gomez
# Mi nombre es : Jaime y mi apellido es : Gomez

# %% [markdown]
# ### 3.- Concatenar números

# %%
# Defino una número

edad = 29 # defino un número

print("Tengo :"  + str(edad)   )  # ERROR print("Tengo :"  + edad) 
print("Tengo :"  , edad)

# %s => es para cadenas
# %d => es para numeros

print("Tengo :%d"%(edad))     # TAMBIEN FUNCIONA print("Tengo :%s"%(edad))
# Out:
# Tengo :29
# Tengo : 29
# Tengo :29

# %%
# definir el año actual es una variable
# que se llama year e imprimirlo

# %% [markdown]
# ### 4.- Concatenar decimales

# %%
# Defino un decimal

dolar = 3.55 # cuanto vale el dolar 

print("El dolar vale :"   + str(dolar)) # ERROR print("Hoy es :"  + dia) 
print("El dolar vale :"   , dolar)
#print("El dolar vale :%s" %(dolar))    # para imprimir cadenas
#print("El dolar vale :%d" %(dolar))    # para imprimir números
print("El dolar vale :%f" %(dolar))    # para imprimir decimales
# Out:
# El dolar vale :3.55
# El dolar vale : 3.55
# El dolar vale :3.550000

# %%
# Definir un decimal en la variable temperatura
# , suponga que la temperatura es 22.35 grados
# , imprmirlo como decimal

# %% [markdown]
# ### 5.- Concatenar : cadenas, números y decimales

# %%
nombre = "Juan" #  defino una cadena
edad = 29       # defino un número
dolar = 3.55    # cuanto vale el dolar 

#mensaje = "¿Como estas " + nombre + " el día de hoy?"
#print(mensaje)

#salida =  "Me llamo " + nombre + ", tengo " + edad + " y solo tengo " + dolar + "soles"
salida =  "Me llamo " + nombre + ", tengo " + str(edad) + " y solo tengo " + str(dolar) + " soles"
print(salida)
# Out:
# Me llamo Juan, tengo 29 y solo tengo 3.55 soles

# %%
nombre = "Juan" #  defino una cadena
edad = 29 # defino un número
dolar = 3.55 # cuanto vale el dolar 

# %.2f   => indica 2 digitos decimales en el número decimal
salida =  ("Me llamo %s, tengo %d y solo tengo %.2f soles " % (nombre, edad, dolar))
print(salida)
# Out:
# Me llamo Juan, tengo 29 y solo tengo 3.55 soles

# %%
nombre = "Juan" #  defino una cadena
edad = 29 # defino un número
dolar = 3.55 # cuanto vale el dolar 

salida =  "Me llamo {}, tengo {} y solo tengo {} ".format(nombre, edad, dolar)
print(salida)
# Out:
# Me llamo Juan, tengo 29 y solo tengo 3.55

# %%
# Tarea de laboratorio
