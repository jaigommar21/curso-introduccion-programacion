# %% [markdown]
# # **Laboratorio 12 : Lectura de archivos**

# %% [markdown]
# ## 1.- Competencias
#
# Conocer y aplicar la sintaxis de lectura de archivos externos de texto para su uso en manipulacion de dats y textos.

# %% [markdown]
# ## 2.- Introducción
#
# Los datos la mayor parte del tiempo son obtenidos de archivos externos, en esta semana vamos hacer uso de la lectura de archivos de texto con Python donde vamos a realizar diferentes tareas.

# %% [markdown]
# ## 3.- Diagrama de flujo
#
# <center>
#   <img width="800" src="https://raw.githubusercontent.com/jgomezm-tecsup/curso-introduccion-programacion/master/_assets/semana_12_diagrama_flujo_lectura_archivo.png" />
# </center>

# %% [markdown]
# ## 4.- Sintaxis
#
# <center>
#   <img width="600" src="https://raw.githubusercontent.com/jgomezm-tecsup/curso-introduccion-programacion/master/_assets/semana_12_sintaxis_lectura_archivo.png" />
# </center>

# %%
# Lectura de archivo

mi_archivo = open("datos.txt","r")

lineas = mi_archivo.readLines()

mi_archivo.close()

print(lineas)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-59f47c24831f> in <module>()
#       1 # Lectura de archivo
#       2
# ----> 3 mi_archivo = open("datos.txt","r")
#       4
#       5 lineas = mi_archivo.readLines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datos.txt'

# %%
print("Mensaje desde una función nueva")
print("Mensaje desde una función nueva")
print("Mensaje desde una función nueva")
# Out:
# Mensaje desde una función nueva
# Mensaje desde una función nueva
# Mensaje desde una función nueva

# %%
probar_funcion()
probar_funcion()
probar_funcion()
# Out:
# Mensaje desde una función nueva
# Mensaje desde una función nueva
# Mensaje desde una función nueva

# %%
# Ejercicio 01 : Crear una función que imprima el mensaje : "Ya estamos en Diciembre", 
#                darle un nombre adecuado.

# Crear la función


# Usar la función

# %%
# Ejercicio 02 : Crear una función que muestre por pantalla los números de 2 a 5, poner un nombre adecuado a la función. 

# Crear la función


# Usar la función

# %% [markdown]
# ### 3.- Tipos de funciones
# Podemos agrupar las funciones en los siguientes tipos:
#
# - Funciones que no requieren datos de ingreso y no retornan ningun valor
# - Funciones que requieren datos de ingreso y no retornan ningun valor
# - Funciones que requieren datos de ingreso y retornan un valor

# %% [markdown]
# #### 3.1.- Funciones que no requieren datos de ingreso y no retornan ningun valor

# %%
# Imprimir un valor constante, este caso ya ha sido visto anteriormente

def imprimir_mensaje():
  print("Hola Mundo...!")

imprimir_mensaje()
# Out:
# Hola Mundo...!

# %%
# Ejercicio 03 : crear un función que imprima los 10 primeros números naturales

# %% [markdown]
# #### 3.2.- Funciones que requieren datos de ingreso y no retornan ningun valor
# Este tipo de funciones requieren que se les pase valores, eso se realiza a través de un conjunto de variables conocidos como parámetros o argumentos.

# %%
# Función para imprimir un mensaje personalizado, 
# se pasa a traves de un parámetro o argumento denominado
# mi_mensaje el valor que se desea imprimir.

def imprimir_mensaje(mi_mensaje):
  print(mi_mensaje)

imprimir_mensaje("Hola Mundo")
imprimir_mensaje("Ya estamos en Diciembre")
# Out:
# Hola Mundo
# Ya estamos en Diciembre

# %%
# Ejercicio 04 : crear un función que me permita pasar como parámetro un valor booleano
#             si es True que imprima "Hola Mundo..!", si el False que imprima "Hello World...!"

# Definir la función
def imprimir_mensaje(var):
  if var :
    print("Hola Mundo..!")
  else:
    print("Hello World...!")

# Usar la función
imprimir_mensaje(True)
imprimir_mensaje(False)
# Out:
# Hola Mundo..!
# Hello World...!

# %%
# Función que recibe mas de un parámetro de entrada

def sumar(a, b):
  print(a+b)

# Suma 2 numeros y lo muestra por pantalla
sumar(3, 4)
# Out:
# 7

# %%
# Ejercicio 05 : crear un función que me permita multiplar 3 números 
#                e imprima el resultado por pantalla
#

# %%
# Función que recibe un argumento de 
# tipo arreglo y los muestra por pantalla

def imprimir(listado_nombres):
  for nombre in listado_nombres :
    print(nombre)

nombres = ["Jaime","Jose","Julietta","Juana"]
imprimir(nombres)
# Out:
# Jaime
# Jose
# Julietta
# Juana

# %%
# Lab : Ejercicio 06 : realizar una función que reciba valores en un arreglo e imprima 
#                      los valores mayores a 5


numeros = [1,2,8,3,14]
imprimir_valores_mayor_5(numeros)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-00418013a1b7> in <module>()
#       4
#       5 numeros = [1,2,8,3,14]
# ----> 6 imprimir_valores_mayor_5(numeros)
#
# NameError: name 'imprimir_valores_mayor_5' is not defined

# %% [markdown]
# #### 3.3.- Funciones que requieren datos de ingreso y retornan un valor
# Este tipo de funciones requieren que se les pase valores, eso se realiza a través de un conjunto de variables conocidos como parámetros o argumentos, y retornan un valor o conjunto de valores al proceso que llamo a la función

# %%
# Función que recibe 2 valores y devuelve la suma

def sumar(var1, var2):
  s = var1 + var2
  return s

ret = sumar(4, 50)
print("El valor de la suma es:", ret)

# %%
# Ejercicio 07 : crear una función que reciba 2 números y devuelva la def resta(var1, var2):

# %%
# LAB : Ejercicio 08 : crear una función que reciba 3 argumentos: Los 2 primeros argumento son valores númericos
#          y el tercer parámetro será una cadena. El funcionamiento es el siguiente de acuerdo 
#          al tercer parámetro:
#               - Si el tercer parámtero es SUMA, devuelve la suma de los 2 primeros parámetros
#               - Si el tercer parámtero es RESTA, devuelve la resta de los 2 primeros parámetros
#               - Si el tercer parámtero es MULTI, devuelve la multiplicación de los 2 primeros parámetros
#               - Si el tercer parámtero es DIV, devuelve la división de los 2 primeros parámetros

# %% [markdown]
# ## 4.- Valores por defecto en una función
# Algunas veces no necesitamos enviar todos los valores que una función necesita, cuando ese es el caso Python nos permite definir valores por defecto.

# %%
# Función que increma un valor 
def incrementar(var1, inc = 1):
   tmp = var1 + inc
   return tmp

nro = 4
# Incrementa el valo en 1
print(incrementar(nro))

# Incrementa el valo en 10
print(incrementar(nro, 10))
# Out:
# 5
# 14

# %%
# Ejercicio 09: realizar una funcion que suma 3 numeros, la función debera tener 3 
#             parámetros, si solo se pasa 2 números, el 3er parámetro debe ser 0 por defecto
# sumar(4,5)
# sumar(4,5,8)

# %% [markdown]
# ## 4.- Conclusiones
# - Las funciones nos permite agrupar funcionalidad y reducir la complejidad de un programa.
# - las funciones puede recibir valores para ser procesados y devolver valores.
