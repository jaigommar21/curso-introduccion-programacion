# %% [markdown]
# # **Resolución de laboratorio 03 : Tipos de datos**

# %% [markdown]
# ## Ejercicio 01
# Escriba un programa en Python que asigne los siguientes valores a las variables var1,
# var2 y var3, imprima los valores cada variable junto con el tipo de datos, de cada una
# de ellas.

# %%
var1 = 1
var2 = "Lima"
var3 = 0.18
print("{} es {}".format(var1, type(var1)))
print("{} es {}".format(var2, type(var2)))
print("{} es {}".format(var3, type(var3)))
# Out:
# 1 es <class 'int'>
# Lima es <class 'str'>
# 0.18 es <class 'float'>

# %% [markdown]
# ## Ejercicio 02
#
# Utilizando operadores de asignación realice lo siguiente:
# - Reste a x el valor de y
# - Halle la división entera de x con respecto a y.
# - Halle x elevado a la y
# - Halle el residuo de x entre y
#
# Considere como valores iniciales:
# - x = 5
# - y = 3
#
# Ahora utilice operadores aritméticos para hallar los mismos resultados.

# %%
# Operadores de asignación
print("Operadores de asignación")
x = 5
y = 3

x -= y
print("x = {}, y = {}".format(x,y))

x **= y
print("x = {}, y = {}".format(x,y))

x %=y
print("x = {}, y = {}".format(x,y))

# Operadores artiméticos
print("Operadores artiméticos")

x = 5
y = 3

x = x - y
print("x = {}, y = {}".format(x,y))

x = x**y
print("x = {}, y = {}".format(x,y))

x = x%y
print("x = {}, y = {}".format(x,y))
# Out:
# Operadores de asignación
# x = 2, y = 3
# x = 8, y = 3
# x = 2, y = 3
# Operadores artiméticos
# x = 2, y = 3
# x = 8, y = 3
# x = 2, y = 3

# %% [markdown]
# ## Ejercicio 03
#
# Un grupo de bacterias se reproducen en un 20% con respecto al día anterior, si el día 1 hay 500 bacterias, ¿Cuantas habrá el día 5? Utilice operadores de asignación y las siguientes variables.
#
# - i = 0
# - texto = "día"
# - inicio = 500
# - incremento = 0.2

# %%
i = 0
texto = "día"
inicio = 500
incremento = 0.2

# Día 1
siguiente_dia = inicio 
i+=1
print("En el {} {} hay {} bacterias".format(texto, i, siguiente_dia))

# Día 2
siguiente_dia *= (1+incremento)         
i+=1
print("En el {} {} hay {} bacterias".format(texto, i, siguiente_dia))

# Día 3
siguiente_dia *= (1+incremento)         
i+=1
print("En el {} {} hay {} bacterias".format(texto, i, siguiente_dia))

# Día 4
siguiente_dia *= (1+incremento)       
i+=1
print("En el {} {} hay {} bacterias".format(texto, i, siguiente_dia))

# Día 5
siguiente_dia *= (1+incremento)      
i+=1
print("En el {} {} hay {} bacterias".format(texto, i, siguiente_dia))
# Out:
# En el día 1 hay 500 bacterias
# En el día 2 hay 600.0 bacterias
# En el día 3 hay 720.0 bacterias
# En el día 4 hay 864.0 bacterias
# En el día 5 hay 1036.8 bacterias
